# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
DATASET_PATH = os.path.join(os.path.abspath(''), "..", "datasets")
os.listdir(DATASET_PATH)
# Out:
# ['.gitkeep',
#  'dcache_synthetic_data.feather',
#  'dirac_pilot_synthetic_data.feather',
#  'dirac_synthetic_data.feather',
#  'it4i_large_synthetic_data.feather',
#  'it4i_synthetic_data.feather',
#  'synthetic_data.feather']

# %%
datasets = {}
for dataset in os.listdir(DATASET_PATH):
    if os.path.isfile(os.path.join(DATASET_PATH, dataset)) and dataset.endswith(".feather"):
        datasets[dataset] = pd.read_feather(os.path.join(DATASET_PATH, dataset))

# %%
datasets["dcache_synthetic_data.feather"].head(5)
# Out:
#                                                                                                                              user_input  \
# 0                                                                 How do I build a docker image for dCache if I am new to the codebase?
# 1                                                                                                 What is FTP in the context of dCache?
# 2  Can you explain how to compile and use the Nearline Storage Plugin with dCache, including the steps for verification and activation?
# 3                                                                                                       How do I use the dCache plugin?
# 4                                                                                   What is NFS version 4 Protocol in relation to ACLs?
#
# ...
